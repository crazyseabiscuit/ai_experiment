# %%
from langchain.prompts import PromptTemplate
from langchain_community.llms import Tongyi  # 导入通义千问Tongyi模型
import dashscope
import os

# 从环境变量获取 dashscope 的 API Key
api_key = os.environ.get('DASHSCOPE_API_KEY')
dashscope.api_key = api_key
 
# 加载 Tongyi 模型
llm = Tongyi(model_name="qwen-turbo", dashscope_api_key=api_key)  # 使用通义千问qwen-turbo模型

# 创建Prompt Template
prompt = PromptTemplate(
    input_variables=["product"],
    template="What is a good name for a company that makes {product}?",
)

# 新推荐用法：将 prompt 和 llm 组合成一个"可运行序列"
chain = prompt | llm

# 使用 invoke 方法传入输入
result1 = chain.invoke({"product": "colorful socks"})
print(result1)
# Out:
# Here are some fun and creative name ideas for a company that makes colorful socks:
#
# ### Playful & Fun:
# 1. **Socktastic**
# 2. **ColorKicks**
# 3. **RainbowToes**
# 4. **Sockapalooza**
# 5. **VividSox**
# 6. **Happy Feet Co.**
# 7. **Stripe Parade**
# 8. **Sassy Socks**
#
# ### Trendy & Modern:
# 9. **ChromaCrew**
# 10. **BoldSox**
# 11. **ThreadTide**
# 12. **DyeMinds**
# 13. **HueHeads**
# 14. **LushLoops**
#
# ### Cute & Quirky:
# 15. **Toe Amigos**
# 16. **Sock Puppets United**
# 17. **Funky Feeters**
# 18. **WiggleWear**
#
# Would you like names that lean more toward luxury, eco-friendly, or something with a specific vibe (e.g., retro, minimalist)? I can tailor them accordingly!

# %%
result2 = chain.invoke({"product": "广告设计"})
print(result2)
# Out:
# A good company name should reflect the creativity, visual appeal, and strategic messaging that 广告设计 (advertising design) entails. Here are some suggestions in both **Chinese** and **English**, along with explanations:
#
# ---
#
# ### 🌟 Chinese Name Ideas for an Advertising Design Company:
#
# 1. **创界广告 (Chuàng Jiè Guǎnggào)**
#    - Meaning: "Creative World Advertising" – suggests innovation and boundary-breaking ideas.
#
# 2. **视点广告设计 (Shìdiǎn Guǎnggào Shèjì)**
#    - Meaning: "Viewpoint Advertising Design" – implies unique perspectives in design and messaging.
#
# 3. **灵动广告 (Língdòng Guǎnggào)**
#    - Meaning: "Agile/Smart Advertising" – conveys creativity and responsiveness.
#
# 4. **光影工坊 (Guāngyǐng Gōngfāng)**
#    - Meaning: "Light and Shadow Workshop" – poetic and artistic, great for visual-based advertising.
#
# 5. **锐意广告设计 (Ruìyì Guǎnggào Shèjì)**
#    - Meaning: "Sharp Ideas Advertising Design" – shows precision and strong intent.
#
# 6. **智绘广告 (Zhìhuì Guǎnggào)**
#    - Meaning: "Smart Art Advertising" – combines intelligence and artistry.
#
# 7. **引力创意 (Yǐnlì Chuànyì)**
#    - Meaning: "Gravity of Creativity" – implies powerful, attention-grabbing creative work.
#
# ---
#
# ### 🌍 English Name Ideas:
#
# 1. **VisionForge Studio**
#    - Combines vision (creative insight) and forging new ideas.
#
# 2. **Pixel & Spark**
#    - A modern name blending digital design ("pixel") and creativity ("spark").
#
# 3. **BrightLens Creative**
#    - Suggests a fresh, insightful perspective on branding and design.
#
# 4. **EchoFrame Studio**
#    - Implies lasting impact and visual storytelling.
#
# 5. **NexaPulse Advertising**
#    - Futuristic and energetic, ideal for a tech-savvy or modern agency.
#
# 6. **Velvet Arrow**
#    - Contrasts softness and strength – elegant yet direct.
#
# 7. **MindCanvas**
#    - A clever play on creativity and strategy – your mind is the canvas for ideas.
#
# ---
#
# ### ✅ Tips for Choosing the Right Name:
# - **Keep it memorable**: Easy to pronounce and spell.
# - **Reflect your brand values**: Is your style bold, elegant, modern, or traditional?
# - **Check domain availability**: Especially if you plan to build a website.
# - **Trademark check**: Make sure the name isn’t already taken legally.
#
# Would you like me to tailor these names to a specific niche, such as digital ads, print media, branding, or social media?
